# %% [markdown]
# # Sudoku solver
#
# ## Solution

# %%
def sudoku_solver(board):
    '''Solve the sudoku.'''
    
    solve_partial_sudoku(board, 0, 0)
    return board

def solve_partial_sudoku(board, row, col):
    '''Solve partial sudoku board.'''
    
    current_row = row
    current_col = col
    
    if current_col == 10:
        current_row += 1
        current_col = 0
        if current_row == 10:
            return True
    
    if board[current_row][current_col] == 0:
        return try_digits_at_position(board, current_row, current_col)
    
    return solve_partial_sudoku(board, current_col + 1, current_row)

def try_digits_at_position(board, row, col):
    
    for digit in range(1, 10):
        if check_value(board, row, col, digit):
            board[row][col] = digit
            if solve_partial_sudoku(board, row, col + 1):
                return True
    
    board[row][col] = 0
    return False
    
def check_value(board, row, col, value):
    '''Check if the board could be a valid sudoku arrangement.'''
    
    is_valid_row = value not in board[row]
    is_valid_col = value not in map(lambda r: r[col], board)
    if not is_valid_row or not is_valid_col:
        return False
    
    row = (row // 3) * 3
    col = (col // 3) * 3
    for i in range(3):
        for j in range(3):
            if value == board[row + i][col + j]:
                return False
    
    return True

# %% [markdown]
# ### Testing

# %%
board = [
    [7, 8, 0, 4, 0, 0, 1, 2, 0],
    [6, 0, 0, 0, 7, 5, 0, 0, 9],
    [0, 0, 0, 6, 0, 1, 0, 7, 8],
    [0, 0, 7, 0, 4, 0, 2, 6, 0],
    [0, 0, 1, 0, 5, 0, 9, 3, 0],
    [9, 0, 4, 0, 6, 0, 0, 0, 5],
    [0, 7, 0, 3, 0, 0, 0, 1, 2],
    [1, 2, 0, 0, 0, 7, 4, 0, 0],
    [0, 4, 9, 2, 0, 6, 0, 0, 7],
]
expected = [
    [7, 8, 5, 4, 3, 9, 1, 2, 6],
    [6, 1, 2, 8, 7, 5, 3, 4, 9],
    [4, 9, 3, 6, 2, 1, 5, 7, 8],
    [8, 5, 7, 9, 4, 3, 2, 6, 1],
    [2, 6, 1, 7, 5, 8, 9, 3, 4],
    [9, 3, 4, 1, 6, 2, 7, 8, 5],
    [5, 7, 8, 3, 9, 4, 6, 1, 2],
    [1, 2, 6, 5, 8, 7, 4, 9, 3],
    [3, 4, 9, 2, 1, 6, 8, 5, 7],
]
assert sudoku_solver(board) == expected
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-73-aa534aeb6ee1> in <module>
#      21     [3, 4, 9, 2, 1, 6, 8, 5, 7],
#      22 ]
# ---> 23 assert sudoku_solver(board) == expected
#
# <ipython-input-72-7bacba6f6408> in sudoku_solver(board)
#       2     '''Solve the sudoku.'''
#       3
# ----> 4     solve_partial_sudoku(board, 0, 0)
#       5     return board
#       6
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      20         return try_digits_at_position(board, current_row, current_col)
#      21
# ---> 22     return solve_partial_sudoku(board, current_col + 1, current_row)
#      23
#      24 def try_digits_at_position(board, row, col):
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      20         return try_digits_at_position(board, current_row, current_col)
#      21
# ---> 22     return solve_partial_sudoku(board, current_col + 1, current_row)
#      23
#      24 def try_digits_at_position(board, row, col):
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      18
#      19     if board[current_row][current_col] == 0:
# ---> 20         return try_digits_at_position(board, current_row, current_col)
#      21
#      22     return solve_partial_sudoku(board, current_col + 1, current_row)
#
# <ipython-input-72-7bacba6f6408> in try_digits_at_position(board, row, col)
#      27         if check_value(board, row, col, digit):
#      28             board[row][col] = digit
# ---> 29             if solve_partial_sudoku(board, row, col + 1):
#      30                 return True
#      31
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      18
#      19     if board[current_row][current_col] == 0:
# ---> 20         return try_digits_at_position(board, current_row, current_col)
#      21
#      22     return solve_partial_sudoku(board, current_col + 1, current_row)
#
# <ipython-input-72-7bacba6f6408> in try_digits_at_position(board, row, col)
#      27         if check_value(board, row, col, digit):
#      28             board[row][col] = digit
# ---> 29             if solve_partial_sudoku(board, row, col + 1):
#      30                 return True
#      31
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      18
#      19     if board[current_row][current_col] == 0:
# ---> 20         return try_digits_at_position(board, current_row, current_col)
#      21
#      22     return solve_partial_sudoku(board, current_col + 1, current_row)
#
# <ipython-input-72-7bacba6f6408> in try_digits_at_position(board, row, col)
#      27         if check_value(board, row, col, digit):
#      28             board[row][col] = digit
# ---> 29             if solve_partial_sudoku(board, row, col + 1):
#      30                 return True
#      31
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      20         return try_digits_at_position(board, current_row, current_col)
#      21
# ---> 22     return solve_partial_sudoku(board, current_col + 1, current_row)
#      23
#      24 def try_digits_at_position(board, row, col):
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      18
#      19     if board[current_row][current_col] == 0:
# ---> 20         return try_digits_at_position(board, current_row, current_col)
#      21
#      22     return solve_partial_sudoku(board, current_col + 1, current_row)
#
# <ipython-input-72-7bacba6f6408> in try_digits_at_position(board, row, col)
#      27         if check_value(board, row, col, digit):
#      28             board[row][col] = digit
# ---> 29             if solve_partial_sudoku(board, row, col + 1):
#      30                 return True
#      31
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      20         return try_digits_at_position(board, current_row, current_col)
#      21
# ---> 22     return solve_partial_sudoku(board, current_col + 1, current_row)
#      23
#      24 def try_digits_at_position(board, row, col):
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      18
#      19     if board[current_row][current_col] == 0:
# ---> 20         return try_digits_at_position(board, current_row, current_col)
#      21
#      22     return solve_partial_sudoku(board, current_col + 1, current_row)
#
# <ipython-input-72-7bacba6f6408> in try_digits_at_position(board, row, col)
#      27         if check_value(board, row, col, digit):
#      28             board[row][col] = digit
# ---> 29             if solve_partial_sudoku(board, row, col + 1):
#      30                 return True
#      31
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      20         return try_digits_at_position(board, current_row, current_col)
#      21
# ---> 22     return solve_partial_sudoku(board, current_col + 1, current_row)
#      23
#      24 def try_digits_at_position(board, row, col):
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      18
#      19     if board[current_row][current_col] == 0:
# ---> 20         return try_digits_at_position(board, current_row, current_col)
#      21
#      22     return solve_partial_sudoku(board, current_col + 1, current_row)
#
# <ipython-input-72-7bacba6f6408> in try_digits_at_position(board, row, col)
#      27         if check_value(board, row, col, digit):
#      28             board[row][col] = digit
# ---> 29             if solve_partial_sudoku(board, row, col + 1):
#      30                 return True
#      31
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      18
#      19     if board[current_row][current_col] == 0:
# ---> 20         return try_digits_at_position(board, current_row, current_col)
#      21
#      22     return solve_partial_sudoku(board, current_col + 1, current_row)
#
# <ipython-input-72-7bacba6f6408> in try_digits_at_position(board, row, col)
#      27         if check_value(board, row, col, digit):
#      28             board[row][col] = digit
# ---> 29             if solve_partial_sudoku(board, row, col + 1):
#      30                 return True
#      31
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      20         return try_digits_at_position(board, current_row, current_col)
#      21
# ---> 22     return solve_partial_sudoku(board, current_col + 1, current_row)
#      23
#      24 def try_digits_at_position(board, row, col):
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      20         return try_digits_at_position(board, current_row, current_col)
#      21
# ---> 22     return solve_partial_sudoku(board, current_col + 1, current_row)
#      23
#      24 def try_digits_at_position(board, row, col):
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      18
#      19     if board[current_row][current_col] == 0:
# ---> 20         return try_digits_at_position(board, current_row, current_col)
#      21
#      22     return solve_partial_sudoku(board, current_col + 1, current_row)
#
# <ipython-input-72-7bacba6f6408> in try_digits_at_position(board, row, col)
#      27         if check_value(board, row, col, digit):
#      28             board[row][col] = digit
# ---> 29             if solve_partial_sudoku(board, row, col + 1):
#      30                 return True
#      31
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      18
#      19     if board[current_row][current_col] == 0:
# ---> 20         return try_digits_at_position(board, current_row, current_col)
#      21
#      22     return solve_partial_sudoku(board, current_col + 1, current_row)
#
# <ipython-input-72-7bacba6f6408> in try_digits_at_position(board, row, col)
#      27         if check_value(board, row, col, digit):
#      28             board[row][col] = digit
# ---> 29             if solve_partial_sudoku(board, row, col + 1):
#      30                 return True
#      31
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      20         return try_digits_at_position(board, current_row, current_col)
#      21
# ---> 22     return solve_partial_sudoku(board, current_col + 1, current_row)
#      23
#      24 def try_digits_at_position(board, row, col):
#
# <ipython-input-72-7bacba6f6408> in solve_partial_sudoku(board, row, col)
#      17             return True
#      18
# ---> 19     if board[current_row][current_col] == 0:
#      20         return try_digits_at_position(board, current_row, current_col)
#      21
#
# IndexError: list index out of range
