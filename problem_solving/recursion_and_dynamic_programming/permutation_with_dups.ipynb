# %% [markdown]
# # Permutation with duplicates
#
# ## Problem statement
#
# Write a method to compute all permutations of a string whose characters are not necessarily unique. The list of permutations should not have duplicates.

# %% [markdown]
# ## Solution

# %%
def perm_with_dups(string):
    
    if isinstance(string, str) == False: return 'ERROR: Input is not a string.'
    
    string_dict = dict(zip(list(string), [0] * len(string)))
    
    for char in string:
        string_dict[char] += 1
    
    return perm_with_dups_helper(string_dict)

# %%
def perm_with_dups_helper(string_dict):
    if sum(string_dict.values()) == 1:
        for char in string_dict:
            if string_dict[char] == 1:
                return [char]
    else:
        result = []
        for char in string_dict:
            if string_dict[char] > 0:
                string_dict[char] -= 1
                for sub_string in perm_with_dups_helper(string_dict):
                    result.append(char + sub_string)
                string_dict[char] += 1
        return result

# %% [markdown]
# #### Test cases

# %%
print(perm_with_dups('a'))
print(perm_with_dups('aa'))
print(perm_with_dups('ab'))
print(perm_with_dups('aab'))
print(perm_with_dups('abc'))
print(perm_with_dups('aaabbc'))
print(perm_with_dups('aaaabbbccd'))
# Out:
# ['a']
# ['aa']
# ['ab', 'ba']
# ['aab', 'aba', 'baa']
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
# ['aaabbc', 'aaabcb', 'aaacbb', 'aababc', 'aabacb', 'aabbac', 'aabbca', 'aabcab', 'aabcba', 'aacabb', 'aacbab', 'aacbba', 'abaabc', 'abaacb', 'ababac', 'ababca', 'abacab', 'abacba', 'abbaac', 'abbaca', 'abbcaa', 'abcaab', 'abcaba', 'abcbaa', 'acaabb', 'acabab', 'acabba', 'acbaab', 'acbaba', 'acbbaa', 'baaabc', 'baaacb', 'baabac', 'baabca', 'baacab', 'baacba', 'babaac', 'babaca', 'babcaa', 'bacaab', 'bacaba', 'bacbaa', 'bbaaac', 'bbaaca', 'bbacaa', 'bbcaaa', 'bcaaab', 'bcaaba', 'bcabaa', 'bcbaaa', 'caaabb', 'caabab', 'caabba', 'cabaab', 'cababa', 'cabbaa', 'cbaaab', 'cbaaba', 'cbabaa', 'cbbaaa']
# ['aaaabbbccd', 'aaaabbbcdc', 'aaaabbbdcc', 'aaaabbcbcd', 'aaaabbcbdc', 'aaaabbccbd', 'aaaabbccdb', 'aaaabbcdbc', 'aaaabbcdcb', 'aaaabbdbcc', 'aaaabbdcbc', 'aaaabbdccb', 'aaaabcbbcd', 'aaaabcbbdc', 'aaaabcbcbd', 'aaaabcbcdb', 'aaaabcbdbc', 'aaaabcbdcb', 'aaaabccbbd', 'aaaabccbdb', 'aaaabccdbb', 'aaaabcdbbc', 'aaaabcdbcb', 'aaaabcdcbb', 'aaaabdbbcc', 'aaaabdbcbc', 'aaaabdbccb', 'aaaabdcbbc', 'aaaabdcbcb', 'aaaabdccbb', 'aaaacbbbcd', 'aaaacbbbdc', 'aaaacbbcbd', 'aaaacbbcdb', 'aaaacbbdbc', 'aaaacbbdcb', 'aaaacbcbbd', 'aaaacbcbdb', 'aaaacbcdbb', 'aaaacbdbbc', 'aaaacbdbcb', 'aaaacbdcbb', 'aaaaccbbbd', 'aaaaccbbdb', 'aaaaccbdbb', 'aaaaccdbbb', 'aaaacdbbbc', 'aaaacdbbcb', 'aaaacdbcbb', 'aaaacdcbbb', 'aaaadbbbcc', 'aaaadbbcbc', 'aaaadbbccb', 'aaaadbcbbc', 'aaaadbcbcb', 'aaaadbccbb', 'aaaadcbbbc', 'aaaadcbbcb', 'aaaadcbcbb', 'aaaadccbbb', 'aaababbccd', 'aaababbcdc', 'aaababbdcc', 'aaababcbcd', 'aaababcbdc', 'aaababccbd', 'aaababccdb', 'aaababcdbc', 'aaababcdcb', 'aaababdbcc', 'aaababdcbc', 'aaababdccb', 'aaabacbbcd', 'aaabacbbdc', 'aaabacbcbd', 'aaabacbcdb', 'aaabacbdbc', 'aaabacbdcb', 'aaabaccbbd', 'aaabaccbdb', 'aaabaccdbb', 'aaabacdbbc', 'aaabacdbcb', 'aaabacdcbb', 'aaabadbbcc', 'aaabadbcbc', 'aaabadbccb', 'aaabadcbbc', 'aaabadcbcb', 'aaabadccbb', 'aaabbabccd', 'aaabbabcdc', 'aaabbabdcc', 'aaabbacbcd', 'aaabbacbdc', 'aaabbaccbd', 'aaabbaccdb', 'aaabbacdbc', 'aaabbacdcb', 'aaabbadbcc', 'aaabbadcbc', 'aaabbadccb', 'aaabbbaccd', 'aaabbbacdc', 'aaabbbadcc', 'aaabbbcacd', 'aaabbbcadc', 'aaabbbccad', 'aaabbbccda', 'aaabbbcdac', 'aaabbbcdca', 'aaabbbdacc', 'aaabbbdcac', 'aaabbbdcca', 'aaabbcabcd', 'aaabbcabdc', 'aaabbcacbd', 'aaabbcacdb', 'aaabbcadbc', 'aaabbcadcb', 'aaabbcbacd', 'aaabbcbadc', 'aaabbcbcad', 'aaabbcbcda', 'aaabbcbdac', 'aaabbcbdca', 'aaabbccabd', 'aaabbccadb', 'aaabbccbad', 'aaabbccbda', 'aaabbccdab', 'aaabbccdba', 'aaabbcdabc', 'aaabbcdacb', 'aaabbcdbac', 'aaabbcdbca', 'aaabbcdcab', 'aaabbcdcba', 'aaabbdabcc', 'aaabbdacbc', 'aaabbdaccb', 'aaabbdbacc', 'aaabbdbcac', 'aaabbdbcca', 'aaabbdcabc', 'aaabbdcacb', 'aaabbdcbac', 'aaabbdcbca', 'aaabbdccab', 'aaabbdccba', 'aaabcabbcd', 'aaabcabbdc', 'aaabcabcbd', 'aaabcabcdb', 'aaabcabdbc', 'aaabcabdcb', 'aaabcacbbd', 'aaabcacbdb', 'aaabcacdbb', 'aaabcadbbc', 'aaabcadbcb', 'aaabcadcbb', 'aaabcbabcd', 'aaabcbabdc', 'aaabcbacbd', 'aaabcbacdb', 'aaabcbadbc', 'aaabcbadcb', 'aaabcbbacd', 'aaabcbbadc', 'aaabcbbcad', 'aaabcbbcda', 'aaabcbbdac', 'aaabcbbdca', 'aaabcbcabd', 'aaabcbcadb', 'aaabcbcbad', 'aaabcbcbda', 'aaabcbcdab', 'aaabcbcdba', 'aaabcbdabc', 'aaabcbdacb', 'aaabcbdbac', 'aaabcbdbca', 'aaabcbdcab', 'aaabcbdcba', 'aaabccabbd', 'aaabccabdb', 'aaabccadbb', 'aaabccbabd', 'aaabccbadb', 'aaabccbbad', 'aaabccbbda', 'aaabccbdab', 'aaabccbdba', 'aaabccdabb', 'aaabccdbab', 'aaabccdbba', 'aaabcdabbc', 'aaabcdabcb', 'aaabcdacbb', 'aaabcdbabc', 'aaabcdbacb', 'aaabcdbbac', 'aaabcdbbca', 'aaabcdbcab', 'aaabcdbcba', 'aaabcdcabb', 'aaabcdcbab', 'aaabcdcbba', 'aaabdabbcc', 'aaabdabcbc', 'aaabdabccb', 'aaabdacbbc', 'aaabdacbcb', 'aaabdaccbb', 'aaabdbabcc', 'aaabdbacbc', 'aaabdbaccb', 'aaabdbbacc', 'aaabdbbcac', 'aaabdbbcca', 'aaabdbcabc', 'aaabdbcacb', 'aaabdbcbac', 'aaabdbcbca', 'aaabdbccab', 'aaabdbccba', 'aaabdcabbc', 'aaabdcabcb', 'aaabdcacbb', 'aaabdcbabc', 'aaabdcbacb', 'aaabdcbbac', 'aaabdcbbca', 'aaabdcbcab', 'aaabdcbcba', 'aaabdccabb', 'aaabdccbab', 'aaabdccbba', 'aaacabbbcd', 'aaacabbbdc', 'aaacabbcbd', 'aaacabbcdb', 'aaacabbdbc', 'aaacabbdcb', 'aaacabcbbd', 'aaacabcbdb', 'aaacabcdbb', 'aaacabdbbc', 'aaacabdbcb', 'aaacabdcbb', 'aaacacbbbd', 'aaacacbbdb', 'aaacacbdbb', 'aaacacdbbb', 'aaacadbbbc', 'aaacadbbcb', 'aaacadbcbb', 'aaacadcbbb', 'aaacbabbcd', 'aaacbabbdc', 'aaacbabcbd', 'aaacbabcdb', 'aaacbabdbc', 'aaacbabdcb', 'aaacbacbbd', 'aaacbacbdb', 'aaacbacdbb', 'aaacbadbbc', 'aaacbadbcb', 'aaacbadcbb', 'aaacbbabcd', 'aaacbbabdc', 'aaacbbacbd', 'aaacbbacdb', 'aaacbbadbc', 'aaacbbadcb', 'aaacbbbacd', 'aaacbbbadc', 'aaacbbbcad', 'aaacbbbcda', 'aaacbbbdac', 'aaacbbbdca', 'aaacbbcabd', 'aaacbbca ...
